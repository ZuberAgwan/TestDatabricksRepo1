# %% [markdown]
# ![Databricks Academy](https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/icons/databricks_academy.png)

# %% [markdown]
# # Lecture - Version Control with Git Overview
#
# ## Overview
#
# Git version control is important because it provides a structured way to manage, track, and collaborate on code changes in software projects. Basically, it is an essential tool for modern software development and DevOps.
#
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
# 1. Describe organizational challenges with version control
# 2. Explain how Git-based repositories work on Databricks
# 3. Integrate GitHub repositories with Databricks
# 4. Identify supported file types in Databricks repos

# %% [markdown]
# ## A. Complications with Version Control
#
# <div class="vcgo-section vcgo-challenges">
# <style>
# .vcgo-section{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .vcgo-section *{box-sizing:border-box;}
# .vcgo-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);overflow:hidden;}
# .vcgo-bar{height:8px;background:#FF5F46;}
# .vcgo-bar.green{background:#00A972;}
# .vcgo-bar.blue{background:#2272B4;}
# .vcgo-bar.maroon{background:#98102A;}
# .vcgo-body{padding:20px;}
# .vcgo-body h3{font-size:18px;line-height:1.25;font-weight:800;margin:0 0 12px 0;color:#0B2026;}
# .vcgo-body p,.vcgo-body li{font-size:16px;line-height:1.5;color:#0B2026;}
# .vcgo-body p{margin:0 0 12px 0;}
# .vcgo-body ul{margin:0;padding-left:22px;}
# .vcgo-body li{margin-bottom:8px;}
# .vcgo-img-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);padding:12px;display:flex;align-items:center;justify-content:center;}
# .vcgo-img-card img{width:100%;max-height:520px;object-fit:contain;border-radius:8px;background:transparent;}
# .vcgo-callout{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:16px 20px;font-size:18px;line-height:1.45;font-weight:700;color:#0B2026;}
# @media screen and (max-width:900px){.vcgo-grid-2,.vcgo-grid-3{grid-template-columns:1fr!important;}.vcgo-img-card{overflow-x:auto;justify-content:flex-start;}.vcgo-img-card img{min-width:820px;}}
# </style>
# <style>
# .vcgo-challenge-grid{display:grid;grid-template-columns:repeat(3,1fr);gap:16px;}
# .vcgo-challenge-card{min-height:170px;background:#F9F7F4;border:1px solid #DCE0E2;border-left:6px solid #FF5F46;border-radius:12px;padding:18px;box-shadow:0 2px 8px rgba(27,49,57,.06);}
# .vcgo-challenge-card:nth-child(2){border-left-color:#98102A;}
# .vcgo-challenge-card:nth-child(3){border-left-color:#2272B4;}
# .vcgo-challenge-card:nth-child(4){border-left-color:#00A972;}
# .vcgo-challenge-card:nth-child(5){border-left-color:#FF5F46;}
# .vcgo-challenge-card h3{font-size:18px;line-height:1.25;margin:0 0 10px 0;font-weight:800;}
# .vcgo-challenge-card p{font-size:16px;line-height:1.45;margin:0;}
# @media screen and (max-width:900px){.vcgo-challenge-grid{grid-template-columns:1fr;}}
# </style>
# <div class="vcgo-callout" style="margin-bottom:18px;">Organizational Challenges</div>
# <div class="vcgo-challenge-grid">
# <div class="vcgo-challenge-card"><h3>Development Silos</h3><p>Silos form over time that isolate development and team operations.</p></div>
# <div class="vcgo-challenge-card"><h3>Lower Software Quality</h3><p>Independent development leads to lower quality due to duplicate code, inconsistent standards, code reviewing, and more.</p></div>
# <div class="vcgo-challenge-card"><h3>Unstable Versioning</h3><p>It can become difficult to track, revert, and audit changes.</p></div>
# <div class="vcgo-challenge-card"><h3>Frequent Updates</h3><p>Without proper version control, managing frequent updates increases risk.</p></div>
# <div class="vcgo-challenge-card"><h3>Scaling Development</h3><p>Branching, merging, and CI/CD integration can become difficult, diminishing the ability to scale development.</p></div>
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>A lack of centralized version control leads to development silos, resulting in duplicate code, inconsistent standards, and lower software quality. Unstable versioning makes tracking, reverting, and auditing changes difficult, increasing risks when managing frequent updates. Additionally, branching, merging, and CI/CD integration become challenging, ultimately limiting scalability.</p>
#
# </details>

# %% [markdown]
# ## B. Secure Code Changes Through Branching
#
# <div class="vcgo-section vcgo-branching">
# <style>
# .vcgo-section{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .vcgo-section *{box-sizing:border-box;}
# .vcgo-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);overflow:hidden;}
# .vcgo-bar{height:8px;background:#FF5F46;}
# .vcgo-bar.green{background:#00A972;}
# .vcgo-bar.blue{background:#2272B4;}
# .vcgo-bar.maroon{background:#98102A;}
# .vcgo-body{padding:20px;}
# .vcgo-body h3{font-size:18px;line-height:1.25;font-weight:800;margin:0 0 12px 0;color:#0B2026;}
# .vcgo-body p,.vcgo-body li{font-size:16px;line-height:1.5;color:#0B2026;}
# .vcgo-body p{margin:0 0 12px 0;}
# .vcgo-body ul{margin:0;padding-left:22px;}
# .vcgo-body li{margin-bottom:8px;}
# .vcgo-img-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);padding:12px;display:flex;align-items:center;justify-content:center;}
# .vcgo-img-card img{width:100%;max-height:520px;object-fit:contain;border-radius:8px;background:transparent;}
# .vcgo-callout{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:16px 20px;font-size:18px;line-height:1.45;font-weight:700;color:#0B2026;}
# @media screen and (max-width:900px){.vcgo-grid-2,.vcgo-grid-3{grid-template-columns:1fr!important;}.vcgo-img-card{overflow-x:auto;justify-content:flex-start;}.vcgo-img-card img{min-width:820px;}}
# </style>
# <style>
# .vcgo-grid-2{display:grid;grid-template-columns:.75fr 1.25fr;gap:20px;align-items:stretch;}
# .vcgo-mini-flow{display:flex;align-items:center;justify-content:center;gap:10px;flex-wrap:wrap;margin-top:16px;}
# .vcgo-pill{background:#F9F7F4;border:1px solid #DCE0E2;border-radius:999px;padding:8px 14px;font-size:15px;font-weight:800;color:#0B2026;}
# .vcgo-arrow{color:#FF5F46;font-size:24px;font-weight:900;}
# </style>
# <div class="vcgo-grid-2">
# <div class="vcgo-card">
# <div class="vcgo-bar"></div>
# <div class="vcgo-body">
# <ul>
# <li>Complementary concept to CI/CD → Enables effective CI</li>
# <li>Version control changes and run through quality control before merging to main branch and deploying</li>
# <li>Example: Gitflow</li>
# </ul>
# </div>
# </div>
# <div class="vcgo-img-card"><img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/gitflow_example.png" alt="Secure code changes through branching"></div>
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>This is an example of a version control and code management over time with Gitflow, which is a common branching strategy that organizes branches for features, releases, and hotfixes.</p>
# <p>Here you will see different versions of a feature (v0.1, v0.2, and v1.0).</p>
# <p>Starting with the first version v0.1 on the main branch, branching occurs to the feature branch where testing and be properly performed in isolation.</p>
# <p>Now that we know how complicated version control can be and we’ve seen an example of what securing code changes looks like, let’s take a look at how Git can be used with Databricks.</p>
#
# </details>

# %% [markdown]
# ## C. Overview of Git with Databricks
#
# <div class="vcgo-section vcgo-git-overview">
# <style>
# .vcgo-section{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .vcgo-section *{box-sizing:border-box;}
# .vcgo-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);overflow:hidden;display:flex;flex-direction:column;}
# .vcgo-bar{height:8px;background:#FF5F46;}
# .vcgo-bar.green{background:#00A972;}
# .vcgo-bar.blue{background:#2272B4;}
# .vcgo-body{padding:20px;display:flex;flex-direction:column;flex:1;}
# .vcgo-body h3{font-size:18px;line-height:1.25;font-weight:800;margin:0 0 12px 0;color:#0B2026;text-align:center;}
# .vcgo-body p,.vcgo-body li{font-size:16px;line-height:1.5;color:#0B2026;}
# .vcgo-body p{margin:0 0 12px 0;}
# .vcgo-body ul{margin:0 0 16px 0;padding-left:22px;}
# .vcgo-body li{margin-bottom:8px;}
# .vcgo-img-box{margin-top:auto;width:100%;min-height:130px;background:#ffffff;border:1px solid #DCE0E2;border-radius:12px;padding:12px;display:flex;align-items:center;justify-content:center;text-align:center;}
# .vcgo-img-box img{display:block;width:100%;max-width:220px;max-height:115px;object-fit:contain;background:transparent;mix-blend-mode:multiply;filter:contrast(1.15) brightness(1);border-radius:4px;margin:0 auto;}
# .vcgo-img-box.wide{flex:1;min-height:260px;}
# .vcgo-img-box.wide img{max-width:310px;max-height:235px;}
# .vcgo-callout{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:16px 20px;font-size:18px;line-height:1.45;font-weight:700;color:#0B2026;}
# .vcgo-grid-3{display:grid;grid-template-columns:repeat(3,1fr);gap:16px;align-items:stretch;}
# @media screen and (max-width:900px){
#   .vcgo-grid-3{grid-template-columns:1fr!important;}
#   .vcgo-img-box img{max-width:260px;}
#   .vcgo-img-box.wide{min-height:220px;}
#   .vcgo-img-box.wide img{max-width:300px;max-height:200px;}
# }
# </style>
#
# <div class="vcgo-callout" style="margin-bottom:18px;">
# Git is a free and open-source software framework designed to track changes in source code during software development.
# </div>
#
# <div class="vcgo-grid-3">
#   <div class="vcgo-card">
#     <div class="vcgo-bar"></div>
#     <div class="vcgo-body">
#       <h3>Common Git Tools and Git-Based Services</h3>
#       <div class="vcgo-img-box wide">
#         <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/tools_git-based_services.png" alt="Common Git Tools and Git-Based Services">
#       </div>
#     </div>
#   </div>
#
#   <div class="vcgo-card">
#     <div class="vcgo-bar green"></div>
#     <div class="vcgo-body">
#       <h3>Benefits of Git</h3>
#       <ul>
#         <li>Collaboration</li>
#         <li>Version Control</li>
#         <li>Branching and Merging</li>
#         <li>Distributed Nature</li>
#         <li>Open Source and Widely Adopted</li>
#       </ul>
#       <div class="vcgo-img-box">
#         <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/benefits_of_git.png" alt="Benefits of Git">
#       </div>
#     </div>
#   </div>
#
#   <div class="vcgo-card">
#     <div class="vcgo-bar blue"></div>
#     <div class="vcgo-body">
#       <h3>Git Integration on Databricks</h3>
#       <ul>
#         <li>Visual Git client and API</li>
#         <li>Supports Common Operations</li>
#         <li>Supports common Git providers</li>
#         <li>Visual diff comparison</li>
#         <li>Designed for authoring and collaborative Lakeflow Jobs</li>
#       </ul>
#       <div class="vcgo-img-box">
#         <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/integration_databricks.png" alt="Git Integration on Databricks">
#       </div>
#     </div>
#   </div>
# </div>
#
# <br>
#
# <div class="vcgo-callout" style="margin-bottom:18px;">
# Integrate 3rd party tools into your Lakeflow Jobs that make sense for your organizational needs.
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>Git Benefits:</p>
# <p>Version control enables tracking code changes, facilitating rollback and collaboration. Branching and merging allow multiple developers to work in parallel and integrate changes efficiently. A distributed job ensures each developer has a full local repository, enhancing flexibility and reliability. Git is optimized for high-performance handling of large projects, and its security features use cryptographic integrity checks to prevent data corruption.</p>
# <p>Git Tools &amp; Services</p>
# <p>GitHub, GitLab, Bitbucket, Azure DevOps</p>
# <p>– Cloud-based repositories with CI/CD, issue tracking, and team collaboration.</p>
# <p>Git CLI &amp; GUI Clients (e.g., SourceTree, GitKraken, VS Code Git Integration)</p>
# <p>– Provides different interfaces for managing repositories.</p>
# <p>CI/CD Integration</p>
# <p>– Automated testing and deployment pipelines.</p>
# <p>Code Review &amp; Collaboration</p>
# <p>– Features like pull requests and merge approvals streamline teamwork.</p>
# <p>Security &amp; Access Control</p>
# <p>– Role-based permissions and audit logs enhance repository security.</p>
# <p>Visual Git Client -</p>
# <p>Databricks provides a user-friendly interface for common Git operations, which we will discuss about on the next slide.</p>
# <p>Seamless Integration -</p>
# <p>Users can leverage remote Git repos while developing code inside Databricks notebooks</p>
# <p>CI/CD Capabilities -</p>
# <p>The repos REST API enables integration of data and AI projects into CI/CD pipelines, allowing users to automate Git Lakeflow Jobs</p>
#
# </details>

# %% [markdown]
# ## D. Generating GitHub Personal Access Token(PAT)
#
# ##### Click the red highlighted box in each step to move to the next step.
#
# <div class="vcgo-pat-flow">
# <style>
# .vcgo-pat-flow{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .vcgo-pat-flow *{box-sizing:border-box;}
# .vcgo-pat-flow input[type="radio"]{display:none;}
# .vcgo-stepbar{display:flex;gap:8px;flex-wrap:wrap;justify-content:flex-start;border-bottom:2px solid #EEEDE9;margin-bottom:16px;}
# .vcgo-stepbar label{padding:10px 14px;border-bottom:3px solid transparent;background:none;font-size:15px;font-weight:800;color:#888;cursor:pointer;margin-bottom:-2px;}
# #vcgo-pat-1:checked ~ .vcgo-stepbar label[for="vcgo-pat-1"],#vcgo-pat-2:checked ~ .vcgo-stepbar label[for="vcgo-pat-2"],#vcgo-pat-3:checked ~ .vcgo-stepbar label[for="vcgo-pat-3"],#vcgo-pat-4:checked ~ .vcgo-stepbar label[for="vcgo-pat-4"],#vcgo-pat-5:checked ~ .vcgo-stepbar label[for="vcgo-pat-5"]{color:#FF5F46;border-bottom-color:#FF5F46;}
# .vcgo-stage{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);padding:16px;overflow:hidden;}
# .vcgo-panel{display:none;}
# #vcgo-pat-1:checked ~ .vcgo-stage .panel-1,#vcgo-pat-2:checked ~ .vcgo-stage .panel-2,#vcgo-pat-3:checked ~ .vcgo-stage .panel-3,#vcgo-pat-4:checked ~ .vcgo-stage .panel-4,#vcgo-pat-5:checked ~ .vcgo-stage .panel-5{display:grid;grid-template-columns:.32fr .68fr;gap:18px;align-items:center;animation:vcgoFade .25s ease both;}
# .vcgo-step-note{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:18px 20px;font-size:18px;line-height:1.45;font-weight:800;color:#0B2026;}
# .vcgo-image-wrap{position:relative;background:#ffffff;border:1px solid #DCE0E2;border-radius:12px;padding:12px;display:flex;align-items:center;justify-content:center;min-height:410px;}
# .vcgo-image-box{position:relative;display:inline-block;max-width:100%;}
# .vcgo-image-box img{display:block;max-width:100%;max-height:520px;object-fit:contain;border-radius:8px;background:transparent;}
# .vcgo-hotspot{position:absolute;border:4px solid #FF5F46;border-radius:4px;background:rgba(255,95,70,.06);box-shadow:0 0 0 5px rgba(255,95,70,.13);cursor:pointer;animation:vcgoPulse 1.25s ease-in-out infinite;}
# .vcgo-hotspot:hover{background:rgba(255,95,70,.14);}
# .hot-settings{left:1.4%;top:61%;width:38%;height:5.6%;}
# .hot-dev{left:4.6%;top:94.6%;width:58%;height:3.9%;}
# .hot-pat{left:8%;top:34%;width:86%;height:54%;}
# .hot-fine{left:54%;top:73%;width:14%;height:14%;}
# .hot-classic{left:71%;top:43%;width:25%;height:30%;}
# .vcgo-reset{display:inline-flex;margin-top:14px;background:#F9F7F4;border:1px solid #DCE0E2;border-radius:999px;padding:8px 13px;font-size:14px;font-weight:800;color:#0B2026;cursor:pointer;}
# @keyframes vcgoPulse{0%,100%{border-color:#FF5F46;box-shadow:0 0 0 5px rgba(255,95,70,.13);}50%{border-color:#98102A;box-shadow:0 0 0 8px rgba(255,95,70,.08);}}
# @keyframes vcgoFade{0%{opacity:0;transform:translateY(6px);}100%{opacity:1;transform:translateY(0);}}
# @media screen and (max-width:900px){#vcgo-pat-1:checked ~ .vcgo-stage .panel-1,#vcgo-pat-2:checked ~ .vcgo-stage .panel-2,#vcgo-pat-3:checked ~ .vcgo-stage .panel-3,#vcgo-pat-4:checked ~ .vcgo-stage .panel-4,#vcgo-pat-5:checked ~ .vcgo-stage .panel-5{grid-template-columns:1fr;}.vcgo-image-wrap{overflow-x:auto;justify-content:flex-start;}.vcgo-stepbar{flex-wrap:wrap;}.vcgo-image-box.wide{min-width:850px;}}
# </style>
#
# <input type="radio" id="vcgo-pat-1" name="vcgo-pat-step" checked>
# <input type="radio" id="vcgo-pat-2" name="vcgo-pat-step">
# <input type="radio" id="vcgo-pat-3" name="vcgo-pat-step">
# <input type="radio" id="vcgo-pat-4" name="vcgo-pat-step">
# <input type="radio" id="vcgo-pat-5" name="vcgo-pat-step">
#
# <div class="vcgo-stepbar">
# <label for="vcgo-pat-1">1. Settings</label>
# <label for="vcgo-pat-2">2. Developer settings</label>
# <label for="vcgo-pat-3">3. Personal access tokens</label>
# <label for="vcgo-pat-4">4. Fine-grained token</label>
# <label for="vcgo-pat-5">5. Classic token</label>
# </div>
#
# <div class="vcgo-stage">
# <div class="vcgo-panel panel-1">
# <div class="vcgo-step-note">Open your GitHub profile menu and select <strong>Settings</strong>.</div>
# <div class="vcgo-image-wrap">
# <div class="vcgo-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/github_settings_menu.png" alt="GitHub profile menu settings">
# <label class="vcgo-hotspot hot-settings" for="vcgo-pat-2" aria-label="Go to Developer settings"></label>
# </div>
# </div>
# </div>
#
# <div class="vcgo-panel panel-2">
# <div class="vcgo-step-note">From the settings page, select <strong>Developer settings</strong>.</div>
# <div class="vcgo-image-wrap">
# <div class="vcgo-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/github_developer_settings.png" alt="GitHub developer settings">
# <label class="vcgo-hotspot hot-dev" for="vcgo-pat-3" aria-label="Go to Personal access tokens"></label>
# </div>
# </div>
# </div>
#
# <div class="vcgo-panel panel-3">
# <div class="vcgo-step-note">Open <strong>Personal access tokens</strong> and choose a token type.</div>
# <div class="vcgo-image-wrap">
# <div class="vcgo-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/github_pat_menu.png" alt="GitHub personal access token menu">
# <label class="vcgo-hotspot hot-pat" for="vcgo-pat-4" aria-label="Go to fine grained token screen"></label>
# </div>
# </div>
# </div>
#
# <div class="vcgo-panel panel-4">
# <div class="vcgo-step-note">For fine-grained tokens, click <strong>Generate new token</strong>.</div>
# <div class="vcgo-image-wrap">
# <div class="vcgo-image-box wide">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/github_fine_grained_tokens.png" alt="GitHub fine-grained personal access tokens">
# <label class="vcgo-hotspot hot-fine" for="vcgo-pat-5" aria-label="Go to classic token screen"></label>
# </div>
# </div>
# </div>
#
# <div class="vcgo-panel panel-5">
# <div class="vcgo-step-note">
# For classic tokens, open <strong>Generate new token</strong> and choose <strong>Generate new token (classic)</strong>.
# <br>
# <label class="vcgo-reset" for="vcgo-pat-1">Start again</label>
# </div>
# <div class="vcgo-image-wrap">
# <div class="vcgo-image-box wide">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/github_classic_tokens.png" alt="GitHub classic personal access token page">
# <label class="vcgo-hotspot hot-classic" for="vcgo-pat-1" aria-label="Start again"></label>
# </div>
# </div>
# </div>
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>To generate a Personal Access Token (PAT) in GitHub, go to <b>Settings → Developer</b> settings, choose either fine-grained or classic tokens, and click Generate new token. Configure the required repository permissions, copy the token, and use it in Databricks for integration.
#
# </details>

# %% [markdown]
# ## E. Connecting to Databricks with GitHub PAT
#
# ##### Click the red highlighted box in each step to move to the next step.
#
# <div class="vcgo-db-pat-flow">
# <style>
# .vcgo-db-pat-flow{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .vcgo-db-pat-flow *{box-sizing:border-box;}
# .vcgo-db-pat-flow input[type="radio"]{display:none;}
# .dbpat-stepbar{display:flex;gap:8px;flex-wrap:wrap;justify-content:flex-start;border-bottom:2px solid #EEEDE9;margin-bottom:16px;}
# .dbpat-stepbar label{padding:10px 14px;border-bottom:3px solid transparent;background:none;font-size:15px;font-weight:800;color:#888;cursor:pointer;margin-bottom:-2px;}
# #dbpat-step-1:checked ~ .dbpat-stepbar label[for="dbpat-step-1"],#dbpat-step-2:checked ~ .dbpat-stepbar label[for="dbpat-step-2"],#dbpat-step-3:checked ~ .dbpat-stepbar label[for="dbpat-step-3"],#dbpat-step-4:checked ~ .dbpat-stepbar label[for="dbpat-step-4"],#dbpat-step-5:checked ~ .dbpat-stepbar label[for="dbpat-step-5"]{color:#FF5F46;border-bottom-color:#FF5F46;}
# .dbpat-stage{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);padding:16px;overflow:hidden;}
# .dbpat-panel{display:none;}
# #dbpat-step-1:checked ~ .dbpat-stage .panel-1,#dbpat-step-2:checked ~ .dbpat-stage .panel-2,#dbpat-step-3:checked ~ .dbpat-stage .panel-3,#dbpat-step-4:checked ~ .dbpat-stage .panel-4,#dbpat-step-5:checked ~ .dbpat-stage .panel-5{display:grid;grid-template-columns:.3fr .7fr;gap:18px;align-items:center;animation:dbpatFade .25s ease both;}
# .dbpat-note{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:18px 20px;font-size:18px;line-height:1.45;font-weight:800;color:#0B2026;}
# .dbpat-image-wrap{position:relative;background:#ffffff;border:1px solid #DCE0E2;border-radius:12px;padding:12px;display:flex;align-items:center;justify-content:center;min-height:410px;}
# .dbpat-image-box{position:relative;display:inline-block;max-width:100%;}
# .dbpat-image-box img{display:block;max-width:100%;max-height:520px;object-fit:contain;border-radius:8px;background:transparent;}
# .dbpat-hotspot{position:absolute;border:4px solid #FF5F46;border-radius:4px;background:rgba(255,95,70,.06);box-shadow:0 0 0 5px rgba(255,95,70,.13);cursor:pointer;animation:dbpatPulse 1.25s ease-in-out infinite;}
# .dbpat-hotspot:hover{background:rgba(255,95,70,.14);}
# .hot-profile{left:15%;top:37%;width:2.2%;height:4.9%;}
# .hot-settings{left:2.1%;top:53.8%;width:5.8%;height:4.5%;}
# .hot-developer{left:25%;top:56.7%;width:5.4%;height:5%;}
# .hot-token-icon{left:39%;top:74%;width:5.7%;height:11%;}
# .hot-token-field{left:50%;top:80%;width:45%;height:17%;}
# .dbpat-reset{display:inline-flex;margin-top:14px;background:#F9F7F4;border:1px solid #DCE0E2;border-radius:999px;padding:8px 13px;font-size:14px;font-weight:800;color:#0B2026;cursor:pointer;}
# @keyframes dbpatPulse{0%,100%{border-color:#FF5F46;box-shadow:0 0 0 5px rgba(255,95,70,.13);}50%{border-color:#98102A;box-shadow:0 0 0 8px rgba(255,95,70,.08);}}
# @keyframes dbpatFade{0%{opacity:0;transform:translateY(6px);}100%{opacity:1;transform:translateY(0);}}
# @media screen and (max-width:900px){#dbpat-step-1:checked ~ .dbpat-stage .panel-1,#dbpat-step-2:checked ~ .dbpat-stage .panel-2,#dbpat-step-3:checked ~ .dbpat-stage .panel-3,#dbpat-step-4:checked ~ .dbpat-stage .panel-4,#dbpat-step-5:checked ~ .dbpat-stage .panel-5{grid-template-columns:1fr;}.dbpat-image-wrap{overflow-x:auto;justify-content:flex-start;}.dbpat-image-box{min-width:850px;}.dbpat-stepbar{flex-wrap:wrap;}}
# </style>
#
# <input type="radio" id="dbpat-step-1" name="dbpat-step" checked>
# <input type="radio" id="dbpat-step-2" name="dbpat-step">
# <input type="radio" id="dbpat-step-3" name="dbpat-step">
# <input type="radio" id="dbpat-step-4" name="dbpat-step">
# <input type="radio" id="dbpat-step-5" name="dbpat-step">
#
# <div class="dbpat-stepbar">
# <label for="dbpat-step-1">1. Profile Menu</label>
# <label for="dbpat-step-2">2. Settings</label>
# <label for="dbpat-step-3">3. Developer</label>
# <label for="dbpat-step-4">4. Token</label>
# <label for="dbpat-step-5">5. Linked Accounts</label>
# </div>
#
# <div class="dbpat-stage">
# <div class="dbpat-panel panel-1">
# <div class="dbpat-note">Open the Databricks user profile menu.</div>
# <div class="dbpat-image-wrap">
# <div class="dbpat-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/seamless_integration.png" alt="Connecting Databricks to GitHub PAT flow">
# <label class="dbpat-hotspot hot-profile" for="dbpat-step-2" aria-label="Go to Settings step"></label>
# </div>
# </div>
# </div>
#
# <div class="dbpat-panel panel-2">
# <div class="dbpat-note">Select <strong>Settings</strong> from the profile menu.</div>
# <div class="dbpat-image-wrap">
# <div class="dbpat-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/seamless_integration.png" alt="Connecting Databricks to GitHub PAT flow">
# <label class="dbpat-hotspot hot-settings" for="dbpat-step-3" aria-label="Go to Developer step"></label>
# </div>
# </div>
# </div>
#
# <div class="dbpat-panel panel-3">
# <div class="dbpat-note">In Settings, select <strong>Developer</strong>.</div>
# <div class="dbpat-image-wrap">
# <div class="dbpat-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/seamless_integration.png" alt="Connecting Databricks to GitHub PAT flow">
# <label class="dbpat-hotspot hot-developer" for="dbpat-step-4" aria-label="Go to Token step"></label>
# </div>
# </div>
# </div>
#
# <div class="dbpat-panel panel-4">
# <div class="dbpat-note">Use the GitHub <strong>Token</strong> to connect Databricks with GitHub.</div>
# <div class="dbpat-image-wrap">
# <div class="dbpat-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/seamless_integration.png" alt="Connecting Databricks to GitHub PAT flow">
# <label class="dbpat-hotspot hot-token-icon" for="dbpat-step-5" aria-label="Go to Linked accounts step"></label>
# </div>
# </div>
# </div>
#
# <div class="dbpat-panel panel-5">
# <div class="dbpat-note">
# In <strong>Linked accounts</strong>, select GitHub and enter the personal access token.
# <br>
# <label class="dbpat-reset" for="dbpat-step-1">Start again</label>
# </div>
# <div class="dbpat-image-wrap">
# <div class="dbpat-image-box">
# <img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/seamless_integration.png" alt="Connecting Databricks to GitHub PAT flow">
# <label class="dbpat-hotspot hot-token-field" for="dbpat-step-1" aria-label="Start again"></label>
# </div>
# </div>
# </div>
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>Setting up a Personal Access Token (PAT) and connecting to your repositories is simple—click your user icon, go to <b>Settings → Developer settings → Personal access tokens</b>, then copy the token into the provided text box. Once saved, your account is linked and ready to use with your repository.</p>
#
# </details>

# %% [markdown]
# ## F. Databricks Git Folders
#
# A **Databricks Git folder** is a folder in your workspace that is linked to a remote Git repository. It lets you run common Git operations — clone, commit, push, pull, and branch — directly from the Databricks UI, without leaving the workspace.
#
# ##### Select each tab below to explore what you can do inside a Databricks Git folder.
#
# <div class="dbgf-flow">
# <style>
# .dbgf-flow{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .dbgf-flow *{box-sizing:border-box;}
# .dbgf-flow input[type="radio"]{display:none;}
# .dbgf-tabs{display:flex;gap:8px;flex-wrap:wrap;border-bottom:2px solid #EEEDE9;margin-bottom:16px;}
# .dbgf-tabs label{padding:10px 14px;border-bottom:3px solid transparent;font-size:15px;font-weight:800;color:#888;cursor:pointer;margin-bottom:-2px;}
# #dbgf-1:checked ~ .dbgf-tabs label[for="dbgf-1"],#dbgf-2:checked ~ .dbgf-tabs label[for="dbgf-2"],#dbgf-3:checked ~ .dbgf-tabs label[for="dbgf-3"],#dbgf-4:checked ~ .dbgf-tabs label[for="dbgf-4"],#dbgf-5:checked ~ .dbgf-tabs label[for="dbgf-5"]{color:#FF5F46;border-bottom-color:#FF5F46;}
# .dbgf-stage{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);padding:18px;}
# .dbgf-panel{display:none;}
# #dbgf-1:checked ~ .dbgf-stage .p1,#dbgf-2:checked ~ .dbgf-stage .p2,#dbgf-3:checked ~ .dbgf-stage .p3,#dbgf-4:checked ~ .dbgf-stage .p4,#dbgf-5:checked ~ .dbgf-stage .p5{display:grid;grid-template-columns:.42fr .58fr;gap:20px;align-items:center;animation:dbgfFade .25s ease both;}
# .dbgf-note{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:18px 20px;}
# .dbgf-note h3{margin:0 0 8px 0;font-size:18px;font-weight:900;color:#0B2026;}
# .dbgf-note p{margin:0;font-size:16px;line-height:1.5;font-weight:600;color:#0B2026;}
# .dbgf-win{width:100%;background:#fff;border:1px solid #DCE0E2;border-radius:12px;box-shadow:0 3px 12px rgba(27,49,57,.07);overflow:hidden;}
# .dbgf-winbar{display:flex;align-items:center;gap:6px;padding:10px 14px;background:#F9F7F4;border-bottom:1px solid #DCE0E2;}
# .dbgf-dot{width:10px;height:10px;border-radius:50%;background:#DCE0E2;}
# .dbgf-wintitle{margin-left:8px;font-size:14px;font-weight:800;color:#0B2026;}
# .dbgf-winbody{padding:16px 18px;}
# .dbgf-lbl{font-size:13px;font-weight:800;color:#5A6B70;margin:2px 0 5px 0;}
# .dbgf-inp{border:2px solid #DCE0E2;border-radius:8px;padding:10px 12px;font-size:13px;color:#0B2026;background:#fff;font-family:Consolas,Monaco,monospace;overflow-x:auto;white-space:nowrap;}
# .dbgf-inp.hl{border-color:#FF5F46;box-shadow:0 0 0 4px rgba(255,95,70,.13);animation:dbgfPulse 1.3s ease-in-out infinite;}
# .dbgf-btn{display:inline-block;margin-top:12px;padding:9px 18px;border-radius:8px;font-size:14px;font-weight:800;color:#fff;}
# .dbgf-btn.blue{background:#2272B4;}
# .dbgf-btn.orange{background:#FF5F46;}
# .dbgf-btn.hl{animation:dbgfPulse 1.3s ease-in-out infinite;box-shadow:0 0 0 4px rgba(34,114,180,.18);}
# .dbgf-chip{display:inline-flex;align-items:center;gap:6px;background:#EAF1F6;border:1px solid #C4D8E6;border-radius:999px;padding:4px 12px;font-size:13px;font-weight:800;color:#2272B4;margin-bottom:10px;}
# .dbgf-file{display:flex;align-items:center;gap:8px;font-family:Consolas,Monaco,monospace;font-size:13px;padding:7px 10px;border:1px solid #EEEDE9;border-radius:8px;margin-top:8px;}
# .dbgf-tag{font-weight:900;font-size:12px;padding:1px 7px;border-radius:5px;}
# .dbgf-tag.add{background:#E6F4EA;color:#1E7B34;}
# .dbgf-branch{border:2px solid #DCE0E2;border-radius:8px;overflow:hidden;max-width:300px;}
# .dbgf-branch div{padding:9px 12px;font-size:14px;font-weight:700;border-bottom:1px solid #EEEDE9;}
# .dbgf-branch div:last-child{border-bottom:none;}
# .dbgf-branch .sel{background:#EAF1F6;color:#2272B4;font-weight:900;}
# .dbgf-diff{font-family:Consolas,Monaco,monospace;font-size:13px;border:1px solid #DCE0E2;border-radius:8px;overflow:hidden;}
# .dbgf-diff div{padding:5px 10px;}
# .dbgf-add{background:#E6F4EA;color:#1E7B34;}
# .dbgf-del{background:#FCE8E6;color:#98102A;}
# .dbgf-ctx{background:#fff;color:#5A6B70;}
# @keyframes dbgfPulse{0%,100%{box-shadow:0 0 0 4px rgba(255,95,70,.13);}50%{box-shadow:0 0 0 7px rgba(255,95,70,.07);}}
# @keyframes dbgfFade{0%{opacity:0;transform:translateY(6px);}100%{opacity:1;transform:translateY(0);}}
# @media screen and (max-width:900px){#dbgf-1:checked ~ .dbgf-stage .p1,#dbgf-2:checked ~ .dbgf-stage .p2,#dbgf-3:checked ~ .dbgf-stage .p3,#dbgf-4:checked ~ .dbgf-stage .p4,#dbgf-5:checked ~ .dbgf-stage .p5{grid-template-columns:1fr;}.dbgf-tabs{flex-wrap:wrap;}}
# </style>
#
# <input type="radio" id="dbgf-1" name="dbgf" checked>
# <input type="radio" id="dbgf-2" name="dbgf">
# <input type="radio" id="dbgf-3" name="dbgf">
# <input type="radio" id="dbgf-4" name="dbgf">
# <input type="radio" id="dbgf-5" name="dbgf">
#
# <div class="dbgf-tabs">
# <label for="dbgf-1">1. Clone a repo</label>
# <label for="dbgf-2">2. Commit &amp; push</label>
# <label for="dbgf-3">3. Pull updates</label>
# <label for="dbgf-4">4. Manage branches</label>
# <label for="dbgf-5">5. Visual validation</label>
# </div>
#
# <div class="dbgf-stage">
#
# <div class="dbgf-panel p1">
# <div class="dbgf-note"><h3>Clone a remote repository</h3><p>Create a Git folder by pasting your repository's <strong>HTTPS URL</strong> into the <em>Create Git folder</em> dialog. Databricks detects the provider automatically and clones the repo into your workspace.</p></div>
# <div class="dbgf-win">
# <div class="dbgf-winbar"><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-wintitle">Create Git folder</span></div>
# <div class="dbgf-winbody">
# <div class="dbgf-lbl">Git repository URL</div>
# <div class="dbgf-inp hl">https://github.com/&lt;your-username&gt;/databricks_devops.git</div>
# <div class="dbgf-lbl" style="margin-top:12px;">Git provider</div>
# <div class="dbgf-inp">GitHub&nbsp;&nbsp;(detected automatically)</div>
# <div class="dbgf-btn blue">Create Git folder</div>
# </div>
# </div>
# </div>
#
# <div class="dbgf-panel p2">
# <div class="dbgf-note"><h3>Commit and push changes using the UI</h3><p>Stage your changes, write a commit message, and push to the remote — all from the Databricks UI, without a terminal.</p></div>
# <div class="dbgf-win">
# <div class="dbgf-winbar"><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-wintitle">databricks_devops</span></div>
# <div class="dbgf-winbody">
# <span class="dbgf-chip">&#9095; main</span>
# <div class="dbgf-lbl">Changes</div>
# <div class="dbgf-file"><span class="dbgf-tag add">A</span>README.md</div>
# <div class="dbgf-lbl" style="margin-top:12px;">Commit message</div>
# <div class="dbgf-inp">First commit</div>
# <div class="dbgf-btn orange hl">Commit &amp; Push</div>
# </div>
# </div>
# </div>
#
# <div class="dbgf-panel p3">
# <div class="dbgf-note"><h3>Pull branch updates</h3><p>Pull the latest commits from the remote branch so your workspace stays in sync with changes made by the rest of your team.</p></div>
# <div class="dbgf-win">
# <div class="dbgf-winbar"><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-wintitle">databricks_devops</span></div>
# <div class="dbgf-winbody">
# <span class="dbgf-chip">&#9095; main</span>
# <div class="dbgf-file"><span class="dbgf-tag add">&#8595;</span>2 new commits on origin/main</div>
# <div class="dbgf-btn blue hl">Pull</div>
# </div>
# </div>
# </div>
#
# <div class="dbgf-panel p4">
# <div class="dbgf-note"><h3>Manage branches</h3><p>Create and switch branches right inside the Git folder to isolate feature work from <strong>main</strong> — the foundation of a safe branching workflow.</p></div>
# <div class="dbgf-win">
# <div class="dbgf-winbar"><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-wintitle">Switch branch</span></div>
# <div class="dbgf-winbody">
# <div class="dbgf-branch"><div class="sel">&#9095; main&nbsp;&nbsp;&#10003;</div><div>&#9095; dev</div></div>
# <div class="dbgf-btn orange">Create Branch</div>
# </div>
# </div>
# </div>
#
# <div class="dbgf-panel p5">
# <div class="dbgf-note"><h3>Visual validation when committing</h3><p>Review a visual diff of exactly what changed before you commit, so you push only what you intend.</p></div>
# <div class="dbgf-win">
# <div class="dbgf-winbar"><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-dot"></span><span class="dbgf-wintitle">README.md &nbsp;&mdash;&nbsp; diff</span></div>
# <div class="dbgf-winbody">
# <div class="dbgf-diff">
# <div class="dbgf-ctx">&nbsp;# Databricks DevOps Training</div>
# <div class="dbgf-del">- My first push.</div>
# <div class="dbgf-add">+ My first push and commit.</div>
# <div class="dbgf-add">+ Added project overview.</div>
# </div>
# </div>
# </div>
# </div>
#
# </div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>Databricks Git folders streamline development by tightly integrating version control systems into the Databricks ecosystem, making it easier to manage code collaboratively while adhering to best practices.</p>
# <p>Use-cases include:</p>
#
# - Collaborative development of machine learning models and ETL pipelines.
# - Source-controlling SQL queries for analytics workloads.
# - Automating deployments through CI/CD pipelines.
#
# <p>Walk through the tabs above to see the core Git-folder operations: cloning a repo by pasting its GitHub URL into the <strong>Create Git folder</strong> dialog, committing and pushing changes from the UI, pulling updates, managing branches, and reviewing a visual diff before you commit.</p>
#
# </details>

# %% [markdown]
# ## G. Git-Based Repos in Databricks
#
# <div style="text-align: center; margin-top: 20px;">
#   <img
#     src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/repos_API_automate_CI-CD.png" alt="Repos API to automate CI/CD"
#     style="width: 1000px; max-width: 100%; height: auto;">
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>1. Aha! Feature:</p>
# <p>DB-3749 W2.0: Projects API private preview with tag and commit based checkouts | Aha!</p>
# <p>2. Description of the features:</p>
# <p>The Repos API provides programmatic access to git-based Re[ps that are part of the Workspace 2.0 effort. With the API, customers can integrate Databricks Repos with their CI/CD workflow. They can programmatically create/update/delete Repos, perform git operations, and specify Git versions when running Jobs based on notebooks in Repos.</p>
# <p>3. Value of the feature (aka what databricks was before this feature, and what this feature will do for databricks)</p>
# <p>Right now, many customers have built workarounds using the Databricks CLI to pull notebooks from Databricks, check them into Git, pull them from Git, and push them back to Databricks. This is not a very robust solution. With Repos and the Repos API we provide a native feature to pull code from a Git repository, check updates back into Git, and programmatically update this Repos using the Repos API</p>
# <p>4. Associated summary slide bullet points: Repos API for CI/CD integration</p>
# <p>5. Cloud: All</p>
# <p>6. Deployment (MT, ST, Azure): GA</p>
#
# </details>

# %% [markdown]
# ## H. Arbitrary Files Support in Repos
#
# <div class="vcgo-section vcgo-files">
# <style>
# .vcgo-section{width:1100px;max-width:100%;margin:16px auto 28px auto;font-family:"DM Sans",-apple-system,BlinkMacSystemFont,"Segoe UI",sans-serif;color:#0B2026;}
# .vcgo-section *{box-sizing:border-box;}
# .vcgo-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);overflow:hidden;}
# .vcgo-bar{height:8px;background:#FF5F46;}
# .vcgo-bar.green{background:#00A972;}
# .vcgo-bar.blue{background:#2272B4;}
# .vcgo-bar.maroon{background:#98102A;}
# .vcgo-body{padding:20px;}
# .vcgo-body h3{font-size:18px;line-height:1.25;font-weight:800;margin:0 0 12px 0;color:#0B2026;}
# .vcgo-body p,.vcgo-body li{font-size:16px;line-height:1.5;color:#0B2026;}
# .vcgo-body p{margin:0 0 12px 0;}
# .vcgo-body ul{margin:0;padding-left:22px;}
# .vcgo-body li{margin-bottom:8px;}
# .vcgo-img-card{background:#ffffff;border:1px solid #DCE0E2;border-radius:14px;box-shadow:0 3px 12px rgba(27,49,57,.07);padding:12px;display:flex;align-items:center;justify-content:center;}
# .vcgo-img-card img{width:100%;max-height:520px;object-fit:contain;border-radius:8px;background:transparent;}
# .vcgo-callout{background:#FFF1EE;border:1px solid #FFD2C9;border-left:6px solid #FF5F46;border-radius:12px;padding:16px 20px;font-size:18px;line-height:1.45;font-weight:700;color:#0B2026;}
# @media screen and (max-width:900px){.vcgo-grid-2,.vcgo-grid-3{grid-template-columns:1fr!important;}.vcgo-img-card{overflow-x:auto;justify-content:flex-start;}.vcgo-img-card img{min-width:820px;}}
# </style>
# <style>
# .vcgo-files-grid{display:grid;grid-template-columns:.9fr 1.1fr;gap:20px;align-items:stretch;}
# .vcgo-file-cards{display:grid;gap:14px;}
# .vcgo-file-card{background:#F9F7F4;border:1px solid #DCE0E2;border-left:6px solid #FF5F46;border-radius:12px;padding:18px;box-shadow:0 2px 8px rgba(27,49,57,.06);}
# .vcgo-file-card:nth-child(2){border-left-color:#00A972;}
# .vcgo-file-card:nth-child(3){border-left-color:#2272B4;}
# .vcgo-file-card:nth-child(4){border-left-color:#98102A;}
# .vcgo-file-card h3{font-size:18px;line-height:1.25;margin:0 0 8px 0;font-weight:850;}
# .vcgo-file-card p{font-size:16px;line-height:1.45;margin:0;}
# </style>
# <div class="vcgo-files-grid">
# <div class="vcgo-file-cards">
# <div class="vcgo-file-card">Portability of code<p>Library files - use Python/R files as packages</p></div>
# <div class="vcgo-file-card">Environment specification portability<p>Build packages from the same repo</p></div>
# <div class="vcgo-file-card">Small data ease of use<p>Relative imports</p></div>
# <div class="vcgo-file-card">Whatever you can do with files “just works”</div>
# </div>
# <div class="vcgo-img-card"><img src="https://files.training.databricks.com/binder/prod_main/devops-essentials-for-data-engineering-en_us-2.2.1/images/20260917T112629Z/DevOps Essentials for Data Engineering/Course Notebooks/Includes/images/lecture_version_control/arbitrary_files_support_in_repos.png" alt="Arbitrary files support in Repos"></div>
# </div>
# <br>
# <div class="vcgo-file-card"><p>.txt &nbsp; .yml &nbsp; .py &nbsp; .csv &nbsp; ...</p></div>
# </div>

# %% [markdown]
# ##### EXPAND FOR ADDITIONAL NOTES
# <details>
#
# <p>Arbitrary files are supported in repos, enabling portability of code for library files like Python and R. This makes it possible to build packages from the same repository, use relative imports, and structure your project in a way that best suits your needs.</p>
#
# </details>

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
