# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #02A36F; color: white; border-radius: 8px; padding: 28px 32px; text-align: center; position: relative;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Lab</div>
#   <div style="font-size: 24pt; font-weight: 700; line-height: 1.3;">Modify Data in a Delta Table</div>
#   <div style="font-size: 14pt; margin-top: 12px; opacity: 0.9;">Practice INSERT, UPDATE, and DELETE on the <code>new_employees</code> table you created in Lab 03.</div>
# </div>
#
# </div>

# %% [markdown]
# ## REQUIRED — SELECT A COMPUTE ENVIRONMENT
#
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Select Serverless Compute</strong>
#   <div style="color:#333;">
#
# Before running this notebook, confirm your compute environment at the top-right of the notebook.
#
# - Click the compute dropdown and select **Serverless** (the default option).
# - If you do not see Serverless available, contact your workspace administrator.
#
# **Note:** This notebook was developed and tested on **Serverless compute**. Other compute options may work but are not guaranteed to behave the same.
#   </div>
# </div>

# %% [markdown]
# ### Setup
# Run the cell below to configure your environment.

# %%
# %run ./Includes/Classroom-Setup-1

# %% [markdown]
# **Where we left off:** In Lesson 02's Practice, you created a `new_employees` table from `employees2.csv`. It should have 2 rows (Maria and Aiden). Let's confirm.
#
# *Prerequisite: You must complete **Lab 03** before starting this activity. The `new_employees` table is created there.*

# %%
# %sql
SELECT * FROM new_employees;

# %% [markdown]
# ### Task 1: Insert a new employee
#
# Add a new row to `new_employees` with the following values:
# - **ID:** 7
# - **FirstName:** Priya
# - **Country:** India
# - **Role:** Data Engineer

# %%
# %sql
-- TODO: Insert Priya into the new_employees table
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>INSERT INTO new_employees (ID, FirstName, Country, Role) VALUES (7, 'Priya', 'India', 'Data Engineer');</code></pre>
#
# </details>

# %% [markdown]
# Verify the insert worked. You should see **3 rows**.

# %%
# %sql
SELECT * FROM new_employees;

# %% [markdown]
# ### Task 2: Update a role
#
# Aiden has been promoted. Update his role from `Data Analyst` to `Senior Data Analyst`.

# %%
# %sql
-- TODO: Update Aiden's role to Senior Data Analyst
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>UPDATE new_employees
# SET Role = 'Senior Data Analyst'
# WHERE FirstName = 'Aiden';</code></pre>
#
# </details>

# %% [markdown]
# Verify the update. Aiden's role should now show `Senior Data Analyst`.

# %%
# %sql
SELECT * FROM new_employees WHERE FirstName = 'Aiden';

# %% [markdown]
# ### Task 3: Delete a row
#
# Priya accepted another offer and won't be joining after all. Remove her record from the table.

# %%
# %sql
-- TODO: Delete Priya from the new_employees table
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>DELETE FROM new_employees
# WHERE FirstName = 'Priya';</code></pre>
#
# </details>

# %% [markdown]
# Verify the delete. You should be back to **2 rows**.

# %%
# %sql
SELECT * FROM new_employees;

# %% [markdown]
# ### Task 4: Check the version history
#
# Use `DESCRIBE HISTORY` to see all the changes you just made to `new_employees`.

# %%
# %sql
-- TODO: Show the version history of new_employees
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>DESCRIBE HISTORY new_employees;</code></pre>
#
# </details>

# %% [markdown]
# You should see 4 versions: the original `CREATE TABLE` (version 0), your INSERT (version 1), UPDATE (version 2), and DELETE (version 3). Every change is tracked automatically.

# %% [markdown]
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
# <div style="margin-top: 10px; padding: 18px 24px; background: #FFF6F4; border: 3px solid #FF5F46; border-radius: 10px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <div style="font-weight: 700; margin-bottom: 8px;">Nice work! You just:</div>
#     <ul style="padding-left: 20px; margin: 0;">
#       <li>Added a row with <code>INSERT INTO</code></li>
#       <li>Changed a value with <code>UPDATE ... SET ... WHERE</code></li>
#       <li>Removed a row with <code>DELETE FROM ... WHERE</code></li>
#       <li>Confirmed all operations are versioned with <code>DESCRIBE HISTORY</code></li>
#     </ul>
#     <div style="margin-top: 12px;">Both your tables now have a full version history.</div>
#   </div>
# </div>
# </div>

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
