# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #02A36F; color: white; border-radius: 8px; padding: 28px 32px; text-align: center; position: relative;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Lab</div>
#   <div style="font-size: 24pt; font-weight: 700; line-height: 1.3;">Find and Create Tables</div>
#   <div style="font-size: 14pt; margin-top: 12px; opacity: 0.9;">Apply what you learned in Lesson 02 to preview a new data file and create a table from it on your own.</div>
# </div>
#
# </div>

# %% [markdown]
# ## REQUIRED — SELECT A COMPUTE ENVIRONMENT
#
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Select Serverless Compute</strong>
#   <div style="color:#333;">
#
# Before running this notebook, confirm your compute environment at the top-right of the notebook.
#
# - Click the compute dropdown and select **Serverless** (the default option).
# - If you do not see Serverless available, contact your workspace administrator.
#
# **Note:** This notebook was developed and tested on **Serverless compute**. Other compute options may work but are not guaranteed to behave the same.
#   </div>
# </div>

# %% [markdown]
# ### Setup
# Run the cell below to configure your environment.

# %%
# %run ./Includes/Classroom-Setup-1

# %% [markdown]
# ### Instructions
#
# In Lesson 02, you found `employees.csv` in your volume and created a table from it. But there was a second file in that volume: **`employees2.csv`**.
#
# In this practice, you will:
# 1. List the files in the volume to confirm `employees2.csv` is there
# 2. Preview the contents of `employees2.csv`
# 3. Create a new table called `new_employees` from that file
# 4. Query your new table to verify it worked
#
# Replace the `<FILL_IN>` placeholders below with the correct SQL. If you get stuck, expand the hint under each task.

# %% [markdown]
# ### Task 1: List the files in the volume
#
# Confirm that `employees2.csv` exists alongside `employees.csv`.

# %%
# TODO: List the files in the myfiles volume
spark.sql(f"LIST '<FILL_IN>'").display()

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# The volume path is `/Volumes/{my_catalog}/{my_schema}/myfiles/`
#
# </details>

# %% [markdown]
# ### Task 2: Preview the new CSV file
#
# Use `read_files` to peek at the contents of `employees2.csv` before creating a table.

# %%
# %sql
-- TODO: Preview the contents of employees2.csv
SELECT * FROM read_files('<FILL_IN>');

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# The full path to the file is `/Volumes/' || my_catalog || '/' || my_schema || '/myfiles/employees2.csv`
#
# </details>

# %% [markdown]
# You should see **2 rows** with the same columns as the original file: ID, FirstName, Country, and Role. These are new employees that haven't been added to a table yet.

# %% [markdown]
# ### Task 3: Create a Delta table from the new file
#
# Use `CREATE TABLE AS SELECT` to create a table called **`new_employees`** from `employees2.csv`.

# %%
# %sql
-- TODO: Create a new Delta table called new_employees from employees2.csv
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# The pattern is the same as Lesson 02:
# <pre><code>CREATE TABLE IF NOT EXISTS new_employees
# AS SELECT * FROM read_files('/Volumes/' || my_catalog || '/' || my_schema || '/myfiles/employees2.csv');</code></pre>
#
# </details>

# %% [markdown]
# ### Task 4: Verify your new table
#
# Query the `new_employees` table to confirm it has the expected data.

# %%
# %sql
-- TODO: Query the new_employees table
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM new_employees;</code></pre>
#
# </details>

# %% [markdown]
# ### Task 5: Check your schema
#
# Run `SHOW TABLES` to see all the tables in your schema. You should now see both `employees` (from Lesson 02) and `new_employees` (from this practice).

# %%
# %sql
SHOW TABLES;

# %% [markdown]
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
# <div style="margin-top: 10px; padding: 18px 24px; background: #FFF6F4; border: 3px solid #FF5F46; border-radius: 10px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <div style="font-weight: 700; margin-bottom: 8px;">Nice work! You just:</div>
#     <ul style="padding-left: 20px; margin: 0;">
#       <li>Found a second data file in your volume</li>
#       <li>Previewed it with <code>read_files</code> before committing to a table</li>
#       <li>Created a new table using <code>CREATE TABLE AS SELECT</code></li>
#       <li>Verified the table exists alongside your Lesson 02 table</li>
#     </ul>
#     <div style="margin-top: 12px;">You now have two tables in your schema, and both were created from raw CSV files using the same pattern.</div>
#   </div>
# </div>
# </div>

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
