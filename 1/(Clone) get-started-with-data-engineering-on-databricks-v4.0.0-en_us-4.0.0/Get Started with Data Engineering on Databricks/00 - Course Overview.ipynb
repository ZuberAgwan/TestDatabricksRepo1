# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Get Started with Databricks for Data Engineering
#
# ## Overview
#
# This course introduces the foundational skills needed to perform a basic data engineering workflow on the **Databricks Data Intelligence Platform**. You will explore the workspace, work with Unity Catalog, and learn the day-to-day building blocks a data engineer uses on Databricks.
#
# The course follows a hands-on path. You start by getting oriented in the workspace, then work through paired Demo and Lab notebooks for each topic. Demos walk you through a concept with the instructor or a guided notebook; Labs ask you to apply what you just saw on your own.
#
# The content covers:
#
# - The Databricks Data Intelligence Platform and how the Databricks workspace, Unity Catalog, and notebooks fit together.
# - Creating and managing **Delta Lake** tables.
# - Modifying data with `INSERT`, `UPDATE`, and `DELETE`.
# - Exploring **version history** and **time travel** on Delta tables.
# - **Ingesting** data with **Lakeflow Connect** options: `CTAS`, the Upload UI, and `COPY INTO`.
# - Building a **Medallion Architecture** pipeline that transforms data through Bronze, Silver, and Gold layers.
# - **Automating** pipelines with **Lakeflow Jobs**.
# - **(Bonus)** Building a declarative pipeline with **Spark Declarative Pipelines**.
#
# By the end of the course, you will be comfortable creating Delta Lake tables, ingesting data into them, transforming that data through a Medallion pipeline, and automating the whole thing as a scheduled job.

# %% [markdown]
# ## Terminal Objectives
#
# By the end of this course, you will be able to:
#
# - **Describe** how the Databricks Data Intelligence Platform unifies data and AI on a single governed foundation.
# - **Navigate** the Databricks workspace, Unity Catalog, and notebooks to locate and work with data.
# - **Create** and **modify** Delta Lake tables using SQL, and **query** previous versions using time travel.
# - **Ingest** data into Delta Lake using multiple methods, including `CTAS`, the Upload UI, and `COPY INTO`.
# - **Build** a Medallion Architecture pipeline that transforms data through Bronze, Silver, and Gold layers.
# - **Automate** a data pipeline using a Lakeflow Job.
# - **(Bonus) Build** a declarative pipeline with **Spark Declarative Pipelines**.
#
# ##### Course version and update information can be found in the `Version Info` file.

# %% [markdown]
# ## A. Prerequisites
#
# Before starting this course, learners should be comfortable with the following:
#
# - **Basic familiarity with cloud data platforms.** You understand what a database, table, and query are at a conceptual level.
# - **Working knowledge of SQL.** You can read and write `SELECT` statements with `WHERE`, `GROUP BY`, and aggregates, and you understand `INSERT`, `UPDATE`, and `DELETE`.
# - **General awareness of data engineering concepts** like data ingestion, transformation, and pipelines is helpful but not required — the course covers the basics.

# %% [markdown]
# ## B. Workspace Setup Information

# %% [markdown]
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
# <strong style="color: #c62828; font-size: 1.1em;">Compute & Permissions</strong>
# <p style="margin: 8px 0 0 0; color: #333;">This content assumes you have:</p>
#
# - **CAN USE access on at least one Serverless compute resource.**
# - **Unity Catalog enabled** in your workspace.
# - **Permission to create tables** in your personal catalog or schema.
# </div>

# %% [markdown]
# ### B1. Databricks Provided Vocareum Workspace (Recommended)
#
# <div style="border-left: 4px solid #1976d2; background: #e3f2fd; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#
# - If you are running this notebook in a **Databricks Academy provided Vocareum workspace**, your Unity Catalog catalog is already created for you.
# - Your catalog name matches your Vocareum username and looks like: **labuser12345** (a unique series of numbers).
# - The course schema (**get_started_de**) is created inside your catalog by the setup script.
#
# </div>

# %% [markdown]
# ### B2. Databricks Free Edition or Other Workspaces (*as is*)
#
# ##### Databricks Free Edition or other workspaces may work for this course, but it is provided **as is** and support is not guaranteed.
#
# <div style="border-left: 4px solid #1976d2; background: #e3f2fd; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#
# #### Catalog Information
#
# - If you are running this notebook in your own Databricks workspace or Databricks Free Edition, the setup will **create a Unity Catalog catalog and schema for you**.
# - The **Create Catalog** permission is required.
# - The catalog name is derived from your Databricks username and follows this pattern: **labuser_username**.
#
# </div>
#
# <div style="border-left: 4px solid #ff9800; background: #fff3e0; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
# <strong style="display:block; color:#e65100; margin-bottom:6px; font-size: 1.1em;">Troubleshooting Setup — Your Workspace Can't Create Catalogs</strong>
# <details>
# <div style="color:#333;">
#
# If you do not have permission to create a new catalog but already have one available, you can explicitly specify an existing catalog by setting the variable in the setup notebook:
#
# `my_catalog = build_user_catalog(catalog_forced='your_catalog_name')`
#
# The `build_user_catalog` function is defined in `./Includes/Classroom-Setup-Common`.
#
# </div>
# </details>
# </div>

# %% [markdown]
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
# <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Do Not Run in Production Environments</strong>
#
# - Only run this course in **development or sandbox workspaces**.
# - Do not run in production environments. The setup scripts create catalogs, schemas, volumes, and tables in your workspace.
# </div>

# %% [markdown]
# ## C. Course Structure
#
# The course is organized as paired **Demo** and **Lab** notebooks. Demos walk you through each concept; Labs ask you to apply it on your own.
#
# | # | Notebook | Type |
# |---|---|---|
# | 00 | Course Overview *(this notebook)* | Reference |
# | 01 | Databricks Workspace Walkthrough | Demo |
# | 02 | Find Your Data and Create a table | Demo |
# | 03 | Find and Create Tables | Lab |
# | 04 | Modify Data with INSERT, UPDATE, and DELETE | Demo |
# | 05 | Modify Data in a Delta Table | Lab |
# | 06 | Explore Version History and Time Travel | Demo |
# | 07 | Use Version History and Time Travel | Lab |
# | 08 | Ingest Data with CTAS and the Upload UI | Demo |
# | 09 | Ingest Data with CTAS | Lab |
# | 10 | Load Data Incrementally with COPY INTO | Demo |
# | 11 | Load Data Incrementally | Lab |
# | 12 | Build a Medallion Architecture Pipeline | Demo |
# | 13 | Build a Complete Medallion Pipeline | Lab |
# | 14 | Automate Your Pipeline with a Lakeflow Job | Demo |
# | 15 | Automate a Pipeline Job | Lab |
# | 16 | Build a Declarative Pipeline with Spark Declarative Pipelines | Demo *(Bonus)* |
# | 17 | Explore Your Declarative Pipeline Results | Lab *(Bonus)* |
# | — | Summary and Next Steps | Reference |
#
# The `Resources` folder contains supporting notebooks for the Lakeflow Job lesson (Task 1 and Task 2). The `Includes` folder contains shared setup scripts and the HTML style guide. **You do not need to run anything in those folders directly** — the lesson notebooks reference them as needed.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
