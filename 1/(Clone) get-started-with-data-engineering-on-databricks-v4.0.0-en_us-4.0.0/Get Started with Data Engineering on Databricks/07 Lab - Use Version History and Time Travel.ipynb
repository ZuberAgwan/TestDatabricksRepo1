# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #02A36F; color: white; border-radius: 8px; padding: 28px 32px; text-align: center; position: relative;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Lab</div>
#   <div style="font-size: 24pt; font-weight: 700; line-height: 1.3;">Use Version History and Time Travel</div>
#   <div style="font-size: 14pt; margin-top: 12px; opacity: 0.9;">Explore the version history of the <code>new_employees</code> table and query its previous states.</div>
# </div>
#
# </div>

# %% [markdown]
# ## REQUIRED — SELECT A COMPUTE ENVIRONMENT
#
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Select Serverless Compute</strong>
#   <div style="color:#333;">
#
# Before running this notebook, confirm your compute environment at the top-right of the notebook.
#
# - Click the compute dropdown and select **Serverless** (the default option).
# - If you do not see Serverless available, contact your workspace administrator.
#
# **Note:** This notebook was developed and tested on **Serverless compute**. Other compute options may work but are not guaranteed to behave the same.
#   </div>
# </div>

# %% [markdown]
# ### Setup
# Run the cell below to configure your environment.

# %%
# %run ./Includes/Classroom-Setup-1

# %% [markdown]
# **Where we left off:** In Lesson 04 Practice, you modified the `new_employees` table with INSERT, UPDATE, and DELETE. It should have a version history with 4 versions (0 through 3). Let's confirm the current state.
#
# *Prerequisite: You must complete **Lab 03** and **Lab 05** before starting this practice. The version history explored here is built by those exercises.*

# %%
# %sql
SELECT * FROM new_employees;

# %% [markdown]
# ### Task 1: View the version history
#
# Use `DESCRIBE HISTORY` to see the full change log for `new_employees`.

# %%
# %sql
-- TODO: Show the version history of new_employees
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>DESCRIBE HISTORY new_employees;</code></pre>
#
# </details>

# %% [markdown]
# Look at the **operation** column for each version. Can you match each version to what you did in Lab 05?
# - Version 0 should be `CREATE TABLE`
# - Version 1 should be `WRITE` (the INSERT)
# - Version 2 should be `UPDATE`
# - Version 3 should be `OPTIMIZE`
# - Version 4 should be `DELETE`
# - Version 5 should be `OPTIMIZE`

# %% [markdown]
# ### Task 2: Query the original version
#
# Query `new_employees` as it was at **version 0**, right after it was created from `employees2.csv`, before any modifications.

# %%
# %sql
-- TODO: Query new_employees at version 0
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM new_employees VERSION AS OF 0;</code></pre>
#
# </details>

# %% [markdown]
# You should see the original 2 rows: Maria as `Data Engineer` and Aiden as `Data Analyst`. No Priya, and no role changes yet.

# %% [markdown]
# ### Task 3: Find a specific change
#
# In Lab 05, you updated Aiden's role. Query the version **right after the INSERT but before the UPDATE** to see Aiden's original role alongside Priya's row.

# %%
# %sql
-- TODO: Query the version that has all 3 rows with original roles (after INSERT, before UPDATE)
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# The INSERT was version 1. Query that version:
# <pre><code>SELECT * FROM new_employees VERSION AS OF 1;</code></pre>
#
# </details>

# %% [markdown]
# You should see 3 rows: Maria, Aiden (still `Data Analyst`), and Priya. This is the state between the INSERT and the UPDATE.

# %% [markdown]
# ### Task 4: Compare current vs. original
#
# Write a query that shows the row count for both the **current version** and **version 0** of `new_employees`. Use UNION ALL to combine the results.

# %%
# %sql
-- TODO: Compare row counts between current and version 0
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT 'Current' AS version, COUNT(*) AS row_count FROM new_employees
# UNION ALL
# SELECT 'Version 0', COUNT(*) FROM new_employees VERSION AS OF 0;</code></pre>
#
# </details>

# %% [markdown]
# Both should show **2 rows**. You started with 2, added 1, then deleted 1. The data is the same size, but the content is different (Aiden's role changed). This is why comparing row counts alone isn't enough; sometimes you need to compare the actual data.

# %% [markdown]
# ### Task 5: Try the shorthand syntax
#
# Query version 0 of `new_employees` using the `@v` shorthand instead of `VERSION AS OF`.

# %%
# %sql
-- TODO: Query version 0 using the @v shorthand
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM new_employees@v0;</code></pre>
#
# </details>

# %% [markdown]
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
# <div style="margin-top: 10px; padding: 18px 24px; background: #FFF6F4; border: 3px solid #FF5F46; border-radius: 10px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <div style="font-weight: 700; margin-bottom: 8px;">Nice work! You just:</div>
#     <ul style="padding-left: 20px; margin: 0;">
#       <li>Inspected the full change log with <code>DESCRIBE HISTORY</code></li>
#       <li>Queried previous versions to see data before it was modified</li>
#       <li>Compared row counts across versions</li>
#       <li>Used the <code>@v</code> shorthand for time travel queries</li>
#     </ul>
#   </div>
# </div>
# </div>

# %% [markdown]
# <!-- CHECKPOINT: Lessons 1-3 -->
#
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #1B5162; color: white; border-radius: 8px; padding: 24px 28px; text-align: center;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Checkpoint</div>
#   <div style="font-size: 20pt; font-weight: 700;">What You've Done So Far</div>
# </div>
#
# <div style="margin-top: 16px; padding: 20px 24px; background: #F9F7F4; border-radius: 8px; box-shadow: 0 2px 8px rgba(27,49,57,0.06);">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.7;">
#     <p>Over Lessons 1 through 3, you:</p>
#     <ul style="padding-left: 20px; margin: 8px 0;">
#       <li>Navigated the Unity Catalog hierarchy to find raw data files in a volume</li>
#       <li>Created Delta tables from CSV files using <code>CREATE TABLE AS SELECT</code></li>
#       <li>Modified data with <code>INSERT</code>, <code>UPDATE</code>, and <code>DELETE</code></li>
#       <li>Viewed the full change log with <code>DESCRIBE HISTORY</code></li>
#       <li>Queried previous versions of your data using time travel</li>
#     </ul>
#     <p>You now have the foundational skills for working with Delta tables: creating them from raw files, modifying their contents, and auditing every change.</p>
#   </div>
# </div>
#
# <div style="margin-top: 16px; padding: 16px 20px; background: #F8F9FC; border-left: 4px solid #1B5162; border-radius: 6px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <strong>Quick self-check:</strong> If a teammate accidentally deleted rows from a table, could you use time travel to see what the data looked like before the delete? Could you explain how to find the right version number?
#   </div>
# </div>

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
