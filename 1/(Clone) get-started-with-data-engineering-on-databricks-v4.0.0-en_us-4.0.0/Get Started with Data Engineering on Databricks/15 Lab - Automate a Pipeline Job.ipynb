# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #02A36F; color: white; border-radius: 8px; padding: 28px 32px; text-align: center; position: relative;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Lab</div>
#   <div style="font-size: 24pt; font-weight: 700; line-height: 1.3;">Automate a Pipeline Job</div>
#   <div style="font-size: 14pt; margin-top: 12px; opacity: 0.9;">Verify your automated pipeline and explore what the job produced.</div>
# </div>
#
# </div>

# %% [markdown]
# ## REQUIRED — SELECT A COMPUTE ENVIRONMENT
#
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Select Serverless Compute</strong>
#   <div style="color:#333;">
#
# Before running this notebook, confirm your compute environment at the top-right of the notebook.
#
# - Click the compute dropdown and select **Serverless** (the default option).
# - If you do not see Serverless available, contact your workspace administrator.
#
# **Note:** This notebook was developed and tested on **Serverless compute**. Other compute options may work but are not guaranteed to behave the same.
#   </div>
# </div>

# %% [markdown]
# ### Setup
# Run the cell below to configure your environment.

# %%
# %run ./Includes/Classroom-Setup-1

# %% [markdown]
# ### Instructions
#
# In Lesson 14, you created a Lakeflow Job that ran the Bronze → Silver → Gold pipeline automatically. Now let's verify what the job produced and compare it to the tables you built manually.

# %% [markdown]
# ### Task 1: Compare manual vs. automated Bronze tables
#
# Query both the manual Bronze table (from Lesson 12) and the job-created Bronze table. Do they have the same data?

# %%
# %sql
SELECT 'Manual (Lesson 12)' AS source, COUNT(*) AS rows FROM current_employees_bronze
UNION ALL
SELECT 'Job (Lesson 14)', COUNT(*) FROM current_employees_bronze_job;

# %% [markdown]
# Both should show **6 rows**. The same data, loaded by the same COPY INTO logic, but one was run interactively and the other by the job.

# %% [markdown]
# ### Task 2: Compare Gold table outputs
#
# Query both Gold tables and compare the aggregations.

# %%
# %sql
-- TODO: Query the manual Gold table from Lesson 12
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM total_roles_gold;</code></pre>
#
# </details>

# %%
# %sql
-- TODO: Query the job-created Gold table from Lesson 14
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM total_roles_gold_job;</code></pre>
#
# </details>

# %% [markdown]
# The results should match. This confirms that the automated job produces the same output as your manual pipeline.

# %% [markdown]
# ### Task 3: Explore the version history of the job tables
#
# Check the version history of `current_employees_bronze_job`. Who made the changes — you or the job?

# %%
# %sql
-- TODO: Show version history of the job's Bronze table
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>DESCRIBE HISTORY current_employees_bronze_job;</code></pre>
#
# </details>

# %% [markdown]
# Notice the **userName** column. It shows the job executed the operations, not your interactive session. This is how you can distinguish manual changes from automated pipeline runs in your audit trail.

# %% [markdown]
# ### Task 4: List all tables in your schema
#
# Run `SHOW TABLES` to see everything you've built across all 8 lessons.

# %%
# %sql
SHOW TABLES;

# %% [markdown]
# You should see tables from every stage of the course: from your first `employees` table in Lesson 02 through the full automated pipeline tables. Each one represents a skill you've built.

# %% [markdown]
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
# <div style="margin-top: 10px; padding: 18px 24px; background: #FFF6F4; border: 3px solid #FF5F46; border-radius: 10px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <div style="font-weight: 700; margin-bottom: 8px;">Nice work! You just:</div>
#     <ul style="padding-left: 20px; margin: 0;">
#       <li>Verified the automated pipeline matches your manual pipeline</li>
#       <li>Compared manual vs. job-created tables</li>
#       <li>Used version history to distinguish interactive changes from automated runs</li>
#     </ul>
#   </div>
# </div>
# </div>

# %% [markdown]
# <!-- FINAL SUMMARY: What You Built -->
#
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #1B5162; color: white; border-radius: 8px; padding: 24px 28px; text-align: center;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Course Complete</div>
#   <div style="font-size: 20pt; font-weight: 700;">What You Built in This Course</div>
# </div>
#
# <div style="margin-top: 16px; padding: 20px 24px; background: #F9F7F4; border-radius: 8px; box-shadow: 0 2px 8px rgba(27,49,57,0.06);">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.7;">
#     <p>Over 7 lessons you:</p>
#     <ul style="padding-left: 20px; margin: 8px 0;">
#       <li>Navigated Unity Catalog to find raw data files in volumes</li>
#       <li>Created Delta tables from CSV files and verified them in Catalog Explorer</li>
#       <li>Modified data with INSERT, UPDATE, and DELETE</li>
#       <li>Used DESCRIBE HISTORY and time travel to audit changes and query previous versions</li>
#       <li>Ingested data three ways: CTAS (programmatic), Upload UI (ad-hoc), and COPY INTO (incremental)</li>
#       <li>Proved COPY INTO's idempotency, safe to re-run, only loads new files</li>
#       <li>Built a Medallion Architecture pipeline: Bronze (raw) → Silver (cleaned) → Gold (aggregated)</li>
#       <li>Explored lineage, permissions, and insights in Catalog Explorer</li>
#       <li>Automated the full pipeline as a Lakeflow Job with task dependencies and scheduling</li>
#     </ul>
#     <p><strong>You went from raw CSV files to an automated, governed data pipeline — the core workflow that data engineers use daily on Databricks.</strong></p>
#   </div>
# </div>
#
# <div style="margin-top: 16px; padding: 16px 20px; background: rgba(0,169,114,0.08); border-left: 4px solid #00A972; border-radius: 6px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <strong>Want to go further?</strong> Lesson 16 is a bonus lesson where you rebuild this same pipeline using <strong>Spark Declarative Pipelines</strong>: a declarative approach that replaces all the manual orchestration with just three SQL statements. If you have time, give it a try!
#   </div>
# </div>
#
# </div>

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
