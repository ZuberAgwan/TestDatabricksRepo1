# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; font-family: sans-serif;">
#
# <div style="background: #02A36F; color: white; border-radius: 8px; padding: 28px 32px; text-align: center; position: relative;">
#   <div style="font-size: 14pt; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; opacity: 0.85; margin-bottom: 8px;">Lab</div>
#   <div style="font-size: 24pt; font-weight: 700; line-height: 1.3;">Ingest Data with CTAS</div>
#   <div style="font-size: 14pt; margin-top: 12px; opacity: 0.9;">Practice creating a table from a file using CTAS with explicit format options and column selection.</div>
# </div>
#
# </div>

# %% [markdown]
# ## REQUIRED — SELECT A COMPUTE ENVIRONMENT
#
# <div style="border-left: 4px solid #f44336; background: #ffebee; padding: 14px 18px; border-radius: 4px; margin: 16px 0;">
#   <strong style="display:block; color:#c62828; margin-bottom:6px; font-size: 1.1em;">Select Serverless Compute</strong>
#   <div style="color:#333;">
#
# Before running this notebook, confirm your compute environment at the top-right of the notebook.
#
# - Click the compute dropdown and select **Serverless** (the default option).
# - If you do not see Serverless available, contact your workspace administrator.
#
# **Note:** This notebook was developed and tested on **Serverless compute**. Other compute options may work but are not guaranteed to behave the same.
#   </div>
# </div>

# %% [markdown]
# ### Setup
# Run the cell below to configure your environment.

# %%
# %run ./Includes/Classroom-Setup-1

# %% [markdown]
# ### Instructions
#
# In Lesson 08, you created `current_employees_ctas` from `employees.csv` using explicit format options. Now you'll do the same thing with `employees2.csv`.
#
# Your goal: create a clean table called **`new_hires_ctas`** from `employees2.csv` with only the 4 data columns.

# %% [markdown]
# ### Task 1: Preview the source file
#
# Before creating the table, preview the contents of `employees2.csv` using `read_files` with explicit format options.

# %%
# %sql
-- TODO: Preview employees2.csv with format options (format, header, inferSchema)
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM read_files(
#   '/Volumes/' || my_catalog || '/' || my_schema || '/myfiles/employees2.csv',
#   format => 'csv',
#   header => true,
#   inferSchema => true
# );</code></pre>
#
# </details>

# %% [markdown]
# ### Task 2: Create the table with column selection
#
# Use CTAS to create a table called **`new_hires_ctas`** from `employees2.csv`. Select only the 4 data columns (ID, FirstName, Country, Role) so the table doesn't include the `_rescued_data` column.

# %%
# %sql
-- TODO: Create new_hires_ctas from employees2.csv with format options and column selection
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>CREATE TABLE IF NOT EXISTS new_hires_ctas AS
# SELECT ID, FirstName, Country, Role
# FROM read_files(
#   '/Volumes/' || my_catalog || '/' || my_schema || '/myfiles/employees2.csv',
#   format => 'csv',
#   header => true,
#   inferSchema => true
# );</code></pre>
#
# </details>

# %% [markdown]
# ### Task 3: Verify the table
#
# Query your new table. You should see 2 rows with exactly 4 columns (no `_rescued_data`).

# %%
# %sql
-- TODO: Query new_hires_ctas
<FILL_IN>

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# <pre><code>SELECT * FROM new_hires_ctas;</code></pre>
#
# </details>

# %% [markdown]
# ### Task 4: Compare column counts
#
# Run the query below to compare the number of columns in `new_hires_ctas` (created with explicit column selection) versus the `employees` table (created with `SELECT *` in Lesson 02). This shows the difference between selecting specific columns and including everything.

# %%
# %sql
SELECT 'new_hires_ctas' AS table_name, COUNT(*) AS column_count
FROM information_schema.columns
WHERE table_schema = my_schema AND table_name = 'new_hires_ctas'
UNION ALL
SELECT 'employees', COUNT(*)
FROM information_schema.columns
WHERE table_schema = my_schema AND table_name = 'employees';

# %% [markdown]
# `new_hires_ctas` should have **4 columns** while `employees` has **5** (including `_rescued_data`). When you specify columns in your CTAS, you get exactly the schema you want.

# %% [markdown]
# <div style="max-width: 900px; margin: 0 auto; font-family: sans-serif;">
# <div style="margin-top: 10px; padding: 18px 24px; background: #FFF6F4; border: 3px solid #FF5F46; border-radius: 10px;">
#   <div style="font-size: 14pt; color: #0b2026; line-height: 1.6;">
#     <div style="font-weight: 700; margin-bottom: 8px;">Nice work! You just:</div>
#     <ul style="padding-left: 20px; margin: 0;">
#       <li>Previewed a file with explicit format options</li>
#       <li>Created a clean table using CTAS with column selection</li>
#       <li>Compared schemas to see the effect of selecting specific columns vs. <code>SELECT *</code></li>
#     </ul>
#     <div style="margin-top: 12px;">Lesson 10 explores COPY INTO, a method designed for loading data incrementally, where new files are picked up automatically and already-processed files are skipped.</div>
#   </div>
# </div>
# </div>

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
