# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Summary and Next Steps

# %% [markdown]
# ## What You Built in This Course
#
# <div style="background: #F9F7F4; border-radius: 10px; padding: 20px 24px; box-shadow: 0 2px 8px rgba(27,49,57,0.06); border-top: 6px solid #1B5162; margin: 16px 0;">
# <div style="font-size: 14pt; color: #0b2026; line-height: 1.7;">
#
# Over the course of these lessons, you went from an empty workspace to a fully automated data engineering pipeline. Specifically, you:
#
# - **Got oriented** in the Databricks workspace and Unity Catalog.
# - **Created and queried** Unity Catalog tables using SQL.
# - **Modified** table data with `INSERT`, `UPDATE`, and `DELETE`.
# - **Used time travel** to query previous versions of a UC table.
# - **Ingested data** with multiple methods: `CTAS`, the Upload UI, and `COPY INTO`.
# - **Built a Medallion Architecture pipeline** that progressively refines data through Bronze, Silver, and Gold layers.
# - **Automated a pipeline** with a Lakeflow Job that runs your transformation work end-to-end.
# - **(Bonus)** Wrote a **Spark Declarative Pipeline** that lets the platform manage orchestration, dependencies, and quality for you.
#
# These are the same building blocks data engineers use in production Databricks workspaces every day.
#
# </div>
# </div>

# %% [markdown]
# ## Continue Building With the Genie Code
#
# <div style="background: #F9F7F4; border-radius: 10px; padding: 20px 24px; box-shadow: 0 2px 8px rgba(27,49,57,0.06); border-top: 6px solid #FF5F46; margin: 16px 0;">
# <div style="font-size: 14pt; color: #0b2026; line-height: 1.7;">
#
# The **Genie Code** lives in every notebook and SQL editor. You can use it to write SQL or Python from natural language, explain code you don't understand, debug error messages, and get suggestions as you type.
#
# Two ways to invoke it:
#
# - Click the **Genie icon** in the right sidebar to open the chat panel.
# - Press **Cmd + I** (Mac) or **Ctrl + I** (Windows) inside any cell to invoke the in-cell Genie Code prompt.
#
# Use it to keep building beyond this course — describe what you want to do in plain language and let Genie Code help draft the code.
#
# </div>
# </div>

# %% [markdown]
# ## A. Additional Resources
#
# Explore these resources to keep learning and stay current with the Databricks Data Intelligence Platform. The links below come straight from the official Databricks documentation and product pages.
#
# #### Core Concepts
#
# - **Delta Lake** documentation:
# [AWS](https://docs.databricks.com/aws/en/delta/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/delta/) |
# [GCP](https://docs.databricks.com/gcp/en/delta/)
#
# - **Unity Catalog** documentation:
# [AWS](https://docs.databricks.com/aws/en/data-governance/unity-catalog/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/data-governance/unity-catalog/) |
# [GCP](https://docs.databricks.com/gcp/en/data-governance/unity-catalog/)
#
# #### Data Ingestion with Lakeflow Connect
#
# - **Lakeflow Connect** product page: [databricks.com/product/data-engineering/lakeflow-connect](https://www.databricks.com/product/data-engineering/lakeflow-connect)
#
# - **What is Lakeflow Connect?** (ingestion overview):
# [AWS](https://docs.databricks.com/aws/en/ingestion/overview) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/ingestion/) |
# [GCP](https://docs.databricks.com/gcp/en/ingestion/overview)
#
# - **Auto Loader** for incremental cloud-storage file ingestion (part of Lakeflow Connect's standard connectors):
# [AWS](https://docs.databricks.com/aws/en/ingestion/cloud-object-storage/auto-loader/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/ingestion/cloud-object-storage/auto-loader/) |
# [GCP](https://docs.databricks.com/gcp/en/ingestion/cloud-object-storage/auto-loader/)
#
# - **`COPY INTO`** SQL reference:
# [AWS](https://docs.databricks.com/aws/en/sql/language-manual/delta-copy-into) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/sql/language-manual/delta-copy-into) |
# [GCP](https://docs.databricks.com/gcp/en/sql/language-manual/delta-copy-into)
#
# #### Pipelines and Orchestration
#
# - **Lakeflow Jobs** (formerly Workflows) — orchestration for production workloads:
# [AWS](https://docs.databricks.com/aws/en/jobs/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/jobs/) |
# [GCP](https://docs.databricks.com/gcp/en/jobs/)
#
# - **Apache Spark™ Declarative Pipelines** (formerly Delta Live Tables / DLT):
# [AWS](https://docs.databricks.com/aws/en/ldp/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/ldp/) |
# [GCP](https://docs.databricks.com/gcp/en/ldp/)
#
# - **What happened to DLT?** Migration guide for the rename:
# [AWS](https://docs.databricks.com/aws/en/ldp/where-is-dlt) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/ldp/where-is-dlt) |
# [GCP](https://docs.databricks.com/gcp/en/ldp/where-is-dlt)
#
# - **Medallion Architecture** overview:
# [AWS](https://docs.databricks.com/aws/en/lakehouse/medallion) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/lakehouse/medallion) |
# [GCP](https://docs.databricks.com/gcp/en/lakehouse/medallion)
#
# #### Productivity and AI Authoring
#
# - **Genie Code** — AI-assisted authoring inside notebooks and the SQL editor:
# [AWS](https://docs.databricks.com/aws/en/genie-code/) |
# [Azure](https://learn.microsoft.com/en-us/azure/databricks/genie-code/) |
# [GCP](https://docs.databricks.com/gcp/en/genie-code/)
#
# - [Introducing Genie Code](https://www.databricks.com/blog/introducing-genie-code) (Databricks blog).
#
# #### Vision and Roadmap
#
# - [Introducing Databricks Lakeflow](https://www.databricks.com/blog/introducing-databricks-lakeflow) — the unified data engineering vision (blog).
#
# - [DAIS 2025: Lakeflow Connect — Smarter, Simpler File Ingestion With the Next Generation of Auto Loader](https://www.databricks.com/dataaisummit/session/lakeflow-connect-smarter-simpler-file-ingestion-next-generation-auto).

# %% [markdown]
# ## B. Next Steps
#
# Continue building your Databricks skills with additional training and certification resources.
#
# ### B1. Continue Your Learning
#
# Recommended next courses to deepen your data engineering skills:
#
# - **[Data Ingestion with Lakeflow Connect](https://www.databricks.com/training/catalog/data-ingestion-with-lakeflow-connect-2968)** — Go deeper on connectors, streaming ingestion, and managed change data capture.
# - **[Build Data Pipelines with Apache Spark™ Declarative Pipelines](https://www.databricks.com/training/catalog/build-data-pipelines-with-apache-spark-declarative-pipelines-1686)** — Build production-grade declarative pipelines with quality and orchestration handled for you.
# - **[Deploy Workloads with Lakeflow Jobs](https://www.databricks.com/training/catalog/deploy-workloads-with-lakeflow-jobs-2978)** — Take Jobs from a single notebook task to multi-step, multi-environment production deployments.
#
# Browse the full catalog at **[Databricks Training and Certification](https://www.databricks.com/learn/training/home)**.
#
# ### B2. Earn a Certification
#
# Validate your Databricks expertise with an official credential. The most common next step after this course is the **Databricks Certified Data Engineer Associate** exam.
#
# Visit **[Databricks Certification and Badging](https://www.databricks.com/learn/training/certification)** for current exam guides and registration.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
